# %%
import pandas as pd

# %%
adult = pd.read_csv('/Users/ecuerbo/Desktop/data/adult.csv')
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
adult['age'].describe()
# Out:
# count    32561.000000
# mean        38.581647
# std         13.640433
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
adult.sex.value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
adult['native.country'].value_counts()
# Out:
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
adult.groupby(by=['native.country'])[['age','hours.per.week']].mean()
# Out:
#                                   age  hours.per.week
# native.country
# ?                           38.725557       41.512864
# Cambodia                    37.789474       40.894737
# Canada                      42.545455       40.404959
# China                       42.533333       37.786667
# Columbia                    39.711864       39.067797
# Cuba                        45.768421       39.157895
# Dominican-Republic          37.728571       42.471429
# Ecuador                     36.642857       39.571429
# El-Salvador                 34.132075       36.792453
# England                     41.155556       41.833333
# France                      38.965517       45.068966
# Germany                     39.255474       41.014599
# Greece                      46.206897       44.241379
# Guatemala                   32.421875       39.234375
# Haiti                       38.272727       36.909091
# Holand-Netherlands          32.000000       40.000000
# ...

# %%
adult[adult['native.country']=='Philippines'][['sex','income']].value_counts(normalize=True)
# Out:
# sex     income
# Male    <=50K     0.383838
# Female  <=50K     0.308081
# Male    >50K      0.247475
# Female  >50K      0.060606
# dtype: float64

# %%
adult[adult['native.country']=='India'][['sex','income']].value_counts(normalize=True)
# Out:
# sex     income
# Male    <=50K     0.51
#         >50K      0.38
# Female  <=50K     0.09
#         >50K      0.02
# dtype: float64

# %%
adult['sex'].nbytes
# Out:
# 260488

# %%
adult['sex'] = adult['sex'].astype("category")
adult['sex'].nbytes
# Out:
# 32577

# %%
adult['sex'].dtype
# Out:
# CategoricalDtype(categories=['Female', 'Male'], ordered=False)

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  category
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: category(1), int64(6), object(8)
# memory usage: 3.5+ MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(data=adult, x='marital.status');

# %%
adult.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
adult['workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
adult.dtypes
# Out:
# age                  int64
# workclass           object
# fnlwgt               int64
# education           object
# education.num        int64
# marital.status      object
# occupation          object
# relationship        object
# race                object
# sex               category
# capital.gain         int64
# capital.loss         int64
# hours.per.week       int64
# native.country      object
# income              object
# dtype: object

# %%
adult_dtypes = {
    "workclass" : "category",
    "education" : "category",
    "relationship":'category'
}

adult2=pd.read_csv(
    '/Users/ecuerbo/Desktop/data/adult.csv',
    dtype=adult_dtypes)
print(adult2.dtypes)
# Out:
# age                  int64
# workclass         category
# fnlwgt               int64
# education         category
# education.num        int64
# marital.status      object
# occupation          object
# relationship      category
# race                object
# sex                 object
# capital.gain         int64
# capital.loss         int64
# hours.per.week       int64
# native.country      object
# income              object
# dtype: object

# %%
adult2['income'].value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: income, dtype: int64

# %%
groupby_object = adult2.groupby(by=['income'])

# %%
groupby_object.mean()
# Out:
#               age        fnlwgt  education.num  capital.gain  capital.loss  \
# income
# <=50K   36.783738  190340.86517       9.595065    148.752468     53.142921
# >50K    44.249841  188005.00000      11.611657   4006.142456    195.001530
#
#         hours.per.week
# income
# <=50K        38.840210
# >50K         45.473026

# %%
adult2.groupby(by=['income']).sum()[['age','education.num']]
# Out:
#            age  education.num
# income
# <=50K   909294         237190
# >50K    346963          91047

# %%
adult2.groupby(by=['income']).median()["age"]
# Out:
# income
# <=50K    34.0
# >50K     44.0
# Name: age, dtype: float64

# %%
gb = adult2.groupby(by=['workclass','income','education'])

# %%
gb.describe()
# Out:
#                                    age                                     \
#                                  count       mean        std   min    25%
# workclass   income education
# ?           <=50K  10th           98.0  33.357143  20.189438  17.0  17.00
#                    11th          118.0  32.372881  19.221514  17.0  18.00
#                    12th           38.0  30.736842  15.611299  17.0  18.00
#                    1st-4th        12.0  63.833333  14.590366  29.0  60.25
#                    5th-6th        28.0  53.642857  20.059567  22.0  38.75
# ...                                ...        ...        ...   ...    ...
# State-gov   >50K   Some-college   31.0  44.322581  10.133729  27.0  37.00
# Without-pay <=50K  7th-8th         1.0  65.000000        NaN  65.0  65.00
#                    Assoc-acdm      1.0  62.000000        NaN  62.0  62.00
#                    HS-grad         9.0  42.555556  22.545017  19.0  21.00
# ...

# %%
# Group the adult dataset by "Sex" and "Above/Below 50k"
gb = adult2.groupby(by=['sex','income'])
gb.size()
# Out:
# sex     income
# Female  <=50K      9592
#         >50K       1179
# Male    <=50K     15128
#         >50K       6662
# dtype: int64

# %%
gb.mean()
# Out:
#                      age         fnlwgt  education.num  capital.gain  \
# sex    income
# Female <=50K   36.210801  185999.381359       9.820475    121.986134
#        >50K    42.125530  183687.406277      11.787108   4200.389313
# Male   <=50K   37.147012  193093.609268       9.452142    165.723823
#        >50K    44.625788  188769.101321      11.580606   3971.765836
#
#                capital.loss  hours.per.week
# sex    income
# Female <=50K      47.364470       35.916701
#        >50K      173.648855       40.426633
# Male   <=50K      56.806782       40.693879
#        >50K      198.780396       46.366106

# %%
# Create a list of user-selected variables
user_list = ['education', 'income']

# %%
#create a group using the above list
gb = adult2.groupby(by=user_list)

# %%
#find the mean for 'hour.per.week' for each group
print(gb['hours.per.week'].mean())
# Out:
# education     income
# 10th          <=50K     36.574053
#               >50K      43.774194
# 11th          <=50K     33.322870
#               >50K      45.133333
# 12th          <=50K     35.035000
#               >50K      44.818182
# 1st-4th       <=50K     37.864198
#               >50K      48.833333
# 5th-6th       <=50K     38.539432
#               >50K      46.000000
# 7th-8th       <=50K     38.830033
#               >50K      47.500000
# 9th           <=50K     37.667351
#               >50K      44.851852
# Assoc-acdm    <=50K     39.264339
#               >50K      44.256604
# Assoc-voc     <=50K     40.817826
#               >50K      43.853186
# Bachelors     <=50K     40.586152
#               >50K      45.475462
# Doctorate     <=50K     45.429907
#               >50K      47.513072
# HS-grad       <=50K     39.727510
#               >50K      45.042985
# Masters       <=50K     41.223822
#               >50K      45.917623
# Preschool     <=50K     36.647059
# ...

# %%
adult2['marital.status'].value_counts()
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital.status, dtype: int64

# %%
adult2['marital.status'] = adult2['marital.status'].astype('category')

# %%
adult2['marital.status'] = adult2['mar ital.status'].cat.set_categories(
    new_categories=['Married-civ-spouse','Never-married','Divorced'])

# %%
#check value counts
adult2['marital.status'].value_counts(dropna=False)
# Out:
# Married-civ-spouse    14976
# Never-married         10683
# Divorced               4443
# NaN                    2459
# Name: marital.status, dtype: int64
