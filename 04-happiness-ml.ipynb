# %%
import os
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/ecuerbo/Desktop/data/happiness2019.csv')
df.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
df.columns = ['country', 'ladder', 'sd_ladder', 'positive_affect',
       'negative_affect', 'social_support', 'freedom', 'corruption',
       'generosity', 'log_gdp_per_capita', 'healthy_life_expectancy']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   country                  156 non-null    object
#  1   ladder                   156 non-null    int64
#  2   sd_ladder                156 non-null    int64
#  3   positive_affect          155 non-null    float64
#  4   negative_affect          155 non-null    float64
#  5   social_support           155 non-null    float64
#  6   freedom                  155 non-null    float64
#  7   corruption               148 non-null    float64
#  8   generosity               155 non-null    float64
#  9   log_gdp_per_capita       152 non-null    float64
#  10  healthy_life_expectancy  150 non-null    float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 13.5+ KB

# %%
df.isnull().sum()
# Out:
# country                    0
# ladder                     0
# sd_ladder                  0
# positive_affect            1
# negative_affect            1
# social_support             1
# freedom                    1
# corruption                 8
# generosity                 1
# log_gdp_per_capita         4
# healthy_life_expectancy    6
# dtype: int64

# %%
df[df.generosity.isna()]
df.drop(28,axis=0,inplace=True)
# Out:
#    country  ladder  sd_ladder  positive_affect  negative_affect  \
# 28   Qatar      29         86              NaN              NaN
#
#     social_support  freedom  corruption  generosity  log_gdp_per_capita  \
# 28             NaN      NaN         NaN         NaN                 1.0
#
#     healthy_life_expectancy
# 28                     43.0

# %%
df.isnull().sum()
# Out:
# country                    0
# ladder                     0
# sd_ladder                  0
# positive_affect            0
# negative_affect            0
# social_support             0
# freedom                    0
# corruption                 7
# generosity                 0
# log_gdp_per_capita         4
# healthy_life_expectancy    6
# dtype: int64

# %%
df[df.corruption.isna()]
# Out:
#                   country  ladder  sd_ladder  positive_affect  \
# 20   United Arab Emirates      21         65             43.0
# 27           Saudi Arabia      28         93             49.0
# 36                Bahrain      37         83             39.0
# 50                 Kuwait      51         98             89.0
# 86           Turkmenistan      87          2            135.0
# 92                  China      93         72             21.0
# 100                Jordan     101        127            112.0
#
#      negative_affect  social_support  freedom  corruption  generosity  \
# 20              56.0            72.0      4.0         NaN        15.0
# 27              82.0            62.0     68.0         NaN        82.0
# 36              83.0            59.0     24.0         NaN        23.0
# 50              97.0            69.0     47.0         NaN        42.0
# 86              63.0             8.0     83.0         NaN        33.0
# ...

# %%
df[df.log_gdp_per_capita.isna()]
# Out:
#              country  ladder  sd_ladder  positive_affect  negative_affect  \
# 24            Taiwan      25         37             17.0              1.0
# 63   Northern Cyprus      64         35            144.0             90.0
# 111          Somalia     112         74              2.0             18.0
# 148            Syria     149        137            155.0            155.0
#
#      social_support  freedom  corruption  generosity  log_gdp_per_capita  \
# 24             48.0    102.0        56.0        56.0                 NaN
# 63             81.0     77.0        29.0        43.0                 NaN
# 111           145.0     14.0        16.0        96.0                 NaN
# 148           154.0    153.0        38.0        69.0                 NaN
#
#      healthy_life_expectancy
# 24                       NaN
# 63                       NaN
# 111                    144.0
# 148                    128.0

# %%
df[df.healthy_life_expectancy.isna()]
# Out:
#                      country  ladder  sd_ladder  positive_affect  \
# 24                    Taiwan      25         37             17.0
# 45                    Kosovo      46        107             71.0
# 63           Northern Cyprus      64         35            144.0
# 75                 Hong Kong      76         33            105.0
# 109  Palestinian Territories     110        110            128.0
# 134                Swaziland     135        104             26.0
#
#      negative_affect  social_support  freedom  corruption  generosity  \
# 24               1.0            48.0    102.0        56.0        56.0
# 45               7.0            85.0     50.0       144.0        31.0
# 63              90.0            81.0     77.0        29.0        43.0
# 75              28.0            76.0     66.0        14.0        18.0
# 109            140.0            82.0    134.0        90.0       147.0
# 134             57.0           103.0    113.0        41.0       145.0
#
# ...

# %%
df.describe()
# Out:
#            ladder   sd_ladder  positive_affect  negative_affect  \
# count  155.000000  155.000000       155.000000       155.000000
# mean    78.819355   78.451613        78.000000        78.000000
# std     45.146870   45.319815        44.888751        44.888751
# min      1.000000    1.000000         1.000000         1.000000
# 25%     40.500000   39.500000        39.500000        39.500000
# 50%     79.000000   78.000000        78.000000        78.000000
# 75%    117.500000  117.500000       116.500000       116.500000
# max    156.000000  156.000000       155.000000       155.000000
#
#        social_support     freedom  corruption  generosity  log_gdp_per_capita  \
# count      155.000000  155.000000  148.000000  155.000000          151.000000
# mean        78.000000   78.000000   74.500000   78.000000           77.000000
# std         44.888751   44.888751   42.868014   44.888751           43.734045
# ...

# %%
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
  
# displaying heatmap
plt.show()

# %%
sns.scatterplot(y='healthy_life_expectancy',x='log_gdp_per_capita',data=df, hue='generosity');

# %%
ph = df[df.country=='Philippines']

# %%
ph
# Out:
#         country  ladder  sd_ladder  positive_affect  negative_affect  \
# 68  Philippines      69        119             42.0            116.0
#
#     social_support  freedom  corruption  generosity  log_gdp_per_capita  \
# 68            75.0     15.0        49.0       115.0                97.0
#
#     healthy_life_expectancy
# 68                     99.0

# %%
ph.plot(kind='bar');

# %%
most_generous = df[df.generosity<=10]
least_generous = df[df.generosity>145]
#print("Most generous country : {}".format(most_generous['country']))
most_generous
# Out:
#             country  ladder  sd_ladder  positive_affect  negative_affect  \
# 3           Iceland       4          9              3.0              3.0
# 4       Netherlands       5          1             12.0             25.0
# 7       New Zealand       8         15             22.0             12.0
# 10        Australia      11         26             47.0             37.0
# 14   United Kingdom      15         16             52.0             42.0
# 15          Ireland      16         34             33.0             32.0
# 21            Malta      22         42             83.0            103.0
# 51         Thailand      52         81             20.0             35.0
# 91        Indonesia      92        108              9.0            104.0
# 130         Myanmar     131         70             45.0             86.0
#
#      social_support  freedom  corruption  generosity  log_gdp_per_capita  \
# 3               1.0      7.0        45.0         3.0                15.0
# ...

# %%
least_generous
# Out:
#                      country  ladder  sd_ladder  positive_affect  \
# 81                    Greece      82         87            102.0
# 88                   Morocco      89        101            110.0
# 89                Azerbaijan      90         24            134.0
# 109  Palestinian Territories     110        110            128.0
# 118                  Georgia     119         51            141.0
# 121               Mauritania     122         68             94.0
# 143                  Lesotho     144        150             72.0
# 144                  Burundi     145        138             98.0
# 147                 Botswana     148        125             87.0
# 150                    Yemen     151         85            153.0
#
#      negative_affect  social_support  freedom  corruption  generosity  \
# 81              94.0           102.0    150.0       123.0       152.0
# 88              91.0           139.0     76.0        84.0       154.0
# ...

# %%
df.head(10)
# Out:
#        country  ladder  sd_ladder  positive_affect  negative_affect  \
# 0      Finland       1          4             41.0             10.0
# 1      Denmark       2         13             24.0             26.0
# 2       Norway       3          8             16.0             29.0
# 3      Iceland       4          9              3.0              3.0
# 4  Netherlands       5          1             12.0             25.0
# 5  Switzerland       6         11             44.0             21.0
# 6       Sweden       7         18             34.0              8.0
# 7  New Zealand       8         15             22.0             12.0
# 8       Canada       9         23             18.0             49.0
# 9      Austria      10         10             64.0             24.0
#
#    social_support  freedom  corruption  generosity  log_gdp_per_capita  \
# 0             2.0      5.0         4.0        47.0                22.0
# 1             4.0      6.0         3.0        22.0                14.0
# ...

# %%
df[df.corruption<=10]
# Out:
#          country  ladder  sd_ladder  positive_affect  negative_affect  \
# 0        Finland       1          4             41.0             10.0
# 1        Denmark       2         13             24.0             26.0
# 2         Norway       3          8             16.0             29.0
# 5    Switzerland       6         11             44.0             21.0
# 6         Sweden       7         18             34.0              8.0
# 7    New Zealand       8         15             22.0             12.0
# 13    Luxembourg      14          3             62.0             19.0
# 15       Ireland      16         34             33.0             32.0
# 33     Singapore      34          5             38.0              2.0
# 151       Rwanda     152         63             54.0            102.0
#
#      social_support  freedom  corruption  generosity  log_gdp_per_capita  \
# 0               2.0      5.0         4.0        47.0                22.0
# ...
